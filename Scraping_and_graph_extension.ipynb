# %% [markdown]
# # Work on citation scraping for each opinions and try to create clusters of opinions based on spectral analysis of an opinions graph

# %%
from bs4 import BeautifulSoup
import pandas
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt
import matplotlib.colors
import networkx as nx
from numpy.linalg import eigh
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# ### Import the opinions sample

# %%
opinions = pandas.read_csv("opinions_sample.csv", sep=";")
print(list(opinions))
# Out:
# ['absolute_url', 'author', 'author_str', 'cluster', 'date_created', 'date_modified', 'download_url', 'extracted_by_ocr', 'html', 'html_lawbox', 'html_with_citations', 'joined_by', 'local_path', 'opinions_cited', 'per_curiam', 'plain_text', 'resource_uri']

# %%
opinions.html[0]
# Out:
# '<p class="case_cite">544 U.S. 917</p>\n    <p class="parties">BERWICK<br><i>v.</i><br>UNITED STATES.</p>\n    <p class="docket">No. 04-8529.</p>\n    <p class="court">Supreme Court of United States.</p>\n    <p class="date">March 21, 2005.</p>\n    <div class="num" id="p1">\n      <span class="num">1</span>\n      <p class="indent">C. A. 2d Cir. Reported below: 107 Fed. Appx. 253. Motions of petitioners for leave to proceed <i>in forma pauperis</i> granted. Certiorari granted, judgments vacated, and cases remanded for further consideration in light of <i>United States</i> v. <i>Booker,</i> 543 U. S. 220 (2005).</p>\n    </div>\n    '

# %%
columns = ['case_cite','parties','docket','court','date','intent']
extracted_data = pandas.DataFrame(columns=columns)

# %% [markdown]
# ### Extract ids for each opinions

# %%
extraction = opinions.absolute_url.str.split('/',expand = True)
extracted_id = extraction[extraction.columns[2]]

# %% [markdown]
# ### Scrap the HTML for each opinions in order to create a new data frame based on HTML class

# %%
missing_html=[]
for i in range(len(opinions.html)):
    case_cite, parties, docket, court, date, indent = (list(),)*6
    try:
        soup = BeautifulSoup(opinions.html[i],"html.parser")
        try:
            case_cite = soup.findAll("p", {"class": "case_cite"})
        except:
            print("No Case Cite")
        try:
            parties = soup.findAll("p", {"class": "parties"})
        except:
            print("No parties")
        try:
            docket = soup.findAll("p", {"class": "docket"})
        except:
            print("No docket")
        try:
            court = soup.findAll("p", {"class": "court"})
        except:
            print("No court")
        try:
            date = soup.findAll("p", {"class": "date"})
        except:
            print("No date")
        try:
            indent = soup.findAll("p", {"class": "indent"})
        except:
            print("No indent")
        extracted_data.loc[i] = [[obs.get_text() for obs in case_cite],[obs.get_text() for obs in parties],[obs.get_text() for obs in docket],[obs.get_text() for obs in court],[obs.get_text() for obs in date],[obs.get_text() for obs in indent]]
    except:
        missing_html.append(i)

# %% [markdown]
# ### Assign the ID for each observation

# %%
extracted_data = extracted_data.assign(id = extracted_id)
extracted_data
# Out:
#                                        case_cite  \
# 0                                 [544 U.S. 917]
# 1                                 [536 U.S. 971]
# 2       [130 U.S. 83, 9 S.Ct. 435, 32 L.Ed. 870]
# 3                                [540 U.S. 1058]
# 5                   [97 U.S. 318, 24 L.Ed. 1008]
# 6                                 [543 U.S. 966]
# 7                                 [537 U.S. 815]
# 8                                [543 U.S. 1024]
# 9                                [544 U.S. 1039]
# 11    [251 U.S. 380, 40 S.Ct. 176, 64 L.Ed. 317]
# 12      [12 U.S. 421, 8 Cranch 421, 3 L.Ed. 610]
# 13                   [94 U.S. 429, 24 L.Ed. 129]
# 14                   [96 U.S. 128, 24 L.Ed. 772]
# 15                                [537 U.S. 961]
# 16                               [537 U.S. 1011]
# 17                                [537 U.S. 933]
# 18                               [538 U.S. 1059]
# 19    [113 U.S. 506, 5 S.Ct. 612, 28 L.Ed. 1102]
# 20      [72 U.S. 509, 18 L.Ed. 524, 5 Wall. 509]
# 21                               [543 U.S. 1070]
# 22                                [544 U.S. 958]
# 23                    [98 U.S. 118, 25 L.Ed. 86]
# 24                                [539 U.S. 961]
# 25                                [543 U.S. 974]
# 26    [254 U.S. 387, 41 S.Ct. 166, 65 L.Ed. 319]
# 27                               [537 U.S. 1224]
# 28                                [544 U.S. 908]
# 29       [44 U.S. 773, 3 How. 773, 11 L.Ed. 824]
# 31                                [543 U.S. 831]
# 33     [222 U.S. 313, 32 S.Ct. 92, 56 L.Ed. 215]
# ...                                          ...
# 4965                              [537 U.S. 838]
# 4966                              [543 U.S. 861]
# 4967                              [539 U.S. 943]
# 4968                              [540 U.S. 944]
# 4969                             [541 U.S. 1049]
# 4970  [255 U.S. 438, 41 S.Ct. 368, 65 L.Ed. 720]
# 4972                              [542 U.S. 965]
# 4974         [26 U.S. 18, 1 Pet. 18, 7 L.Ed. 34]
# 4975  [191 U.S. 341, 24 S.Ct. 114, 48 L.Ed. 211]
# 4979                              [544 U.S. 944]
# 4980                             [543 U.S. 1070]
# 4981                              [540 U.S. 926]
# 4982                              [537 U.S. 918]
# 4983                              [536 U.S. 966]
# 4984                             [538 U.S. 1013]
# 4985     [43 U.S. 397, 2 How. 397, 11 L.Ed. 314]
# 4986      [29 U.S. 172, 4 Pet. 172, 7 L.Ed. 821]
# 4987                              [538 U.S. 989]
# 4988                             [537 U.S. 1113]
# 4989                              [543 U.S. 817]
# 4990                              [543 U.S. 972]
# 4991                              [538 U.S. 904]
# 4992                             [538 U.S. 1035]
# 4993                              [537 U.S. 885]
# 4994                             [543 U.S. 1049]
# 4995                              [543 U.S. 973]
# 4996                              [540 U.S. 816]
# 4997                             [540 U.S. 1079]
# 4998  [135 U.S. 309, 10 S.Ct. 831, 34 L.Ed. 210]
# 4999                              [540 U.S. 909]
#
#                                                 parties           docket  \
# 0                             [BERWICKv.UNITED STATES.]   [No. 04-8529.]
# 1                             [MORALESv.UNITED STATES.]  [No. 01-10512.]
# 2           [CALTONv.PEOPLE OF THE TERRITORY OF UTAH.1]               []
# 3                              [SAMSONv.LEWIS, WARDEN.]   [No. 03-6710.]
# 5                                      [HURLEYv.JONES.]               []
# 6     [STRONGv.McCUSKEY, JUDGE, UNITED STATES DISTRI...   [No. 04-6246.]
# 7     [GRID RADIO ET AL.v.FEDERAL COMMUNICATIONS COM...   [No. 01-1662.]
[CERTIORARI TO THE UNITED STATES COURT OF APPE...  124369
# 16    [CERTIORARI TO THE UNITED STATES COURT OF APPE...  124905
# 17    [CERTIORARI TO THE UNITED STATES COURT OF APPE...  123990
# 18    [CERTIORARI TO THE UNITED STATES COURT OF APPE...  129977
# 19    [This was a bill in equity filed in the court ...   91307
# 20    [ERROR to the Circuit Court for the District o...   87849
# 21    [C. A. 9th Cir. Certiorari denied. Reported be...  141215
# 22    [C. A. 10th Cir. Reported below: 116 Fed. Appx...  143599
# 23    [ERROR to the Circuit Court of the United Stat...   89853
# 24    [Appeal from the C. A. 4th Cir., Certiorari de...  130882
# 25    [C. A. 10th Cir. Certiorari denied. Reported b...  139991
# 26    [Mr. H. T. Newcomb, of New York City, for appe...   99681
# 27    [CERTIORARI TO THE UNITED STATES COURT OF APPE...  127605
# 28                    [Sup. Ct. Va. Certiorari denied.]  142991
# 29    [THIS case was brought up, by writ of error, f...   86348
# 31    [C. A. 2d Cir. Certiorari denied. Reported bel...  138132
# 33    [Messrs. John W. Beckwith, Joseph F. Grossman,...   97501
# ...                                                 ...     ...
# 4965  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  122709
# 4966  [Sup. Ct. Neb. Certiorari denied. Reported bel...  138546
# 4967  [Appeal from the C. A. 11th Cir., Certiorari d...  130678
# 4968           [Petition for writs of mandamus denied.]  133027
# 4969  [C. A. 5th Cir. Certiorari denied. Reported be...  136369
# 4970  [Mr. Assistant Attorney General Garnett, for p...   99757
# 4972  [C. A. 10th Cir. Certiorari granted. Reported ...  137711
# 4974  [IN the Circuit Court of the United States, fo...   85560
# 4975  [The plaintiff in error has sued out this writ...   95951
# 4979     [543 U.S. 447. Petition for rehearing denied.]  143402
# 4980  [App. Ct. Ill., 1st Dist. Certiorari denied. R...  141213
# 4981  [Appeal from the C. A. 4th Cir., Certiorari de...  132810
# 4982  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  123771
# 4983               [C. A. 11th Cir. Certiorari denied.]  121945
# 4984  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  129360
# 4985  [THIS case was brought up by writ of error, fr...   86287
# 4986  [THIS case came before the court, on a divisio...   85697
# 4987  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  129051
# 4988  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  126219
# 4989  [Ct. App. Ind. Certiorari denied. Reported bel...  137955
# 4990                [C. A. 5th Cir. Certiorari denied.]  139962
# 4991  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  127948
# 4992  [CERTIORARI TO THE SUPREME COURT OF IOWA., Sup...  129640
# 4993  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  123332
# 4994       [Petitions for writs of prohibition denied.]  140925
# 4995  [C. A. 11th Cir. Certiorari denied. Reported b...  139985
# 4996  [Appeal from the C. A. 4th Cir., Certiorari de...  131341
# 4997  [Appeal from the C. A. 6th Cir., Certiorari de...  134602
# 4998  [[Statement of Case from pages 309-311 intenti...   92783
# 4999  [Appeal from the C. A. 2d Cir., Certiorari den...  132586
#
# [4655 rows x 7 columns]

# %%
extracted_data.case_cite = [[id.split(id.split()[1]) for id in case] for case in extracted_data.case_cite]
extracted_data
# Out:
#                                      case_cite  \
# 0                               [[544 ,  917]]
# 1                               [[536 ,  971]]
# 2       [[130 ,  83], [9 ,  435], [32 ,  870]]
# 3                              [[540 ,  1058]]
# 5                  [[97 ,  318], [24 ,  1008]]
# 6                               [[543 ,  966]]
# 7                               [[537 ,  815]]
# 8                              [[543 ,  1024]]
# 9                              [[544 ,  1039]]
[CERTIORARI TO THE UNITED STATES COURT OF APPE...  129977
# 19    [This was a bill in equity filed in the court ...   91307
# 20    [ERROR to the Circuit Court for the District o...   87849
# 21    [C. A. 9th Cir. Certiorari denied. Reported be...  141215
# 22    [C. A. 10th Cir. Reported below: 116 Fed. Appx...  143599
# 23    [ERROR to the Circuit Court of the United Stat...   89853
# 24    [Appeal from the C. A. 4th Cir., Certiorari de...  130882
# 25    [C. A. 10th Cir. Certiorari denied. Reported b...  139991
# 26    [Mr. H. T. Newcomb, of New York City, for appe...   99681
# 27    [CERTIORARI TO THE UNITED STATES COURT OF APPE...  127605
# 28                    [Sup. Ct. Va. Certiorari denied.]  142991
# 29    [THIS case was brought up, by writ of error, f...   86348
# 31    [C. A. 2d Cir. Certiorari denied. Reported bel...  138132
# 33    [Messrs. John W. Beckwith, Joseph F. Grossman,...   97501
# ...                                                 ...     ...
# 4965  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  122709
# 4966  [Sup. Ct. Neb. Certiorari denied. Reported bel...  138546
# 4967  [Appeal from the C. A. 11th Cir., Certiorari d...  130678
# 4968           [Petition for writs of mandamus denied.]  133027
# 4969  [C. A. 5th Cir. Certiorari denied. Reported be...  136369
# 4970  [Mr. Assistant Attorney General Garnett, for p...   99757
# 4972  [C. A. 10th Cir. Certiorari granted. Reported ...  137711
# 4974  [IN the Circuit Court of the United States, fo...   85560
# 4975  [The plaintiff in error has sued out this writ...   95951
# 4979     [543 U.S. 447. Petition for rehearing denied.]  143402
# 4980  [App. Ct. Ill., 1st Dist. Certiorari denied. R...  141213
# 4981  [Appeal from the C. A. 4th Cir., Certiorari de...  132810
# 4982  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  123771
# 4983               [C. A. 11th Cir. Certiorari denied.]  121945
# 4984  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  129360
# 4985  [THIS case was brought up by writ of error, fr...   86287
# 4986  [THIS case came before the court, on a divisio...   85697
# 4987  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  129051
# 4988  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  126219
# 4989  [Ct. App. Ind. Certiorari denied. Reported bel...  137955
# 4990                [C. A. 5th Cir. Certiorari denied.]  139962
# 4991  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  127948
# 4992  [CERTIORARI TO THE SUPREME COURT OF IOWA., Sup...  129640
# 4993  [CERTIORARI TO THE UNITED STATES COURT OF APPE...  123332
# 4994       [Petitions for writs of prohibition denied.]  140925
# 4995  [C. A. 11th Cir. Certiorari denied. Reported b...  139985
# 4996  [Appeal from the C. A. 4th Cir., Certiorari de...  131341
# 4997  [Appeal from the C. A. 6th Cir., Certiorari de...  134602
# 4998  [[Statement of Case from pages 309-311 intenti...   92783
# 4999  [Appeal from the C. A. 2d Cir., Certiorari den...  132586
#
# [4655 rows x 7 columns]

# %% [markdown]
# ### Create a sub dataframe with id and case cited

# %%
int_list = []
for index, element in extracted_data.iterrows():
        try :
            citation = ([(id[0]+id[1]) for id in element.case_cite])
            int_list.append(list(citation))
        except:
            int_list.append([]) 
            
extracted_data.case_cite = int_list
case_relation = pandas.concat([extracted_data.id, extracted_data.case_cite], axis = 1)

# %%
int_list = []
for index, element in extracted_data.iterrows():
    try :
        int_list.append(list(map(int, element.case_cite)))
    except:
        int_list.append([])
extracted_data.case_cite = int_list
case_relation = pandas.concat([extracted_data.id, extracted_data.case_cite], axis = 1)

# %%
case_relation.head()
# Out:
#         id                     case_cite
# 0   143119                    [544  917]
# 1   122028                    [536  971]
# 2    92451    [130  83, 9  435, 32  870]
# 3   134300                   [540  1058]
# 5    89793           [97  318, 24  1008]
# 6   139897                    [543  966]
# 7   122421                    [537  815]
# 8   140645                   [543  1024]
# 9   144705                   [544  1039]
# 11   99504  [251  380, 40  176, 64  317]

# %% [markdown]
# ### Create a graph based on relation between cases

# %%
case_cite_graph = nx.DiGraph()

for index, element in case_relation.iterrows():
    case_cite_graph.add_node(element.id, attr_dict={"is_case": True})
    for link in element.case_cite:
        case_cite_graph.add_node(link, attr_dict={"is_case": False})
        case_cite_graph.add_edge(element.id, link)

# %%
# %matplotlib inline
plt.figure(figsize=(40,40))
colors = ['r' if case_cite_graph.node[n]['is_case'] else 'b' for n in case_cite_graph]
nx.draw_networkx(case_cite_graph, node_size=80, pos = nx.spring_layout(case_cite_graph),node_color=colors, linewidths=0, width=0.1, with_labels = False)
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-45e38240158a> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.figure(figsize=(40,40))
# ----> 3 colors = ['r' if case_cite_graph.node[n]['is_case'] else 'b' for n in case_cite_graph]
#       4 nx.draw_networkx(case_cite_graph, node_size=80, pos = nx.spring_layout(case_cite_graph), linewidths=0, width=0.1, with_labels = False)#node_color=colors,
#       5 plt.axis('off')
#
# <ipython-input-109-45e38240158a> in <listcomp>(.0)
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.figure(figsize=(40,40))
# ----> 3 colors = ['r' if case_cite_graph.node[n]['is_case'] else 'b' for n in case_cite_graph]
#       4 nx.draw_networkx(case_cite_graph, node_size=80, pos = nx.spring_layout(case_cite_graph), linewidths=0, width=0.1, with_labels = False)#node_color=colors,
#       5 plt.axis('off')
#
# KeyError: 'is_case'

# %% [markdown]
# ### Centrality computation of graph

# %%
from collections import Counter

# %%
## Most common cases : 544 US 971, 537 US 1149, 543 US 872
stats = nx.closeness_centrality(case_cite_graph)
closness = Counter(stats).most_common()[:3]
print(closness)
# Out:
# [('544  971', 0.0007055918151349444), ('537  1149', 0.0006173928382430764), ('543  872', 0.0006173928382430764)]

# %%
stats = nx.in_degree_centrality(case_cite_graph)
in_degree = Counter(stats).most_common()[:3]
print(in_degree)
# Out:
# [('544  971', 0.0007055918151349444), ('537  1149', 0.0006173928382430764), ('543  872', 0.0006173928382430764)]

# %%
stats = nx.out_degree_centrality(case_cite_graph)
out_degree = Counter(stats).most_common()[:3]
print(out_degree)
# Out:
# [('92961', 0.0004409948844593403), ('99621', 0.0003527959075674722), ('93063', 0.0003527959075674722)]

# %%
stats = nx.degree(case_cite_graph)
degree = Counter(stats).most_common()[:3]
print(stats)
# Out:
', 3), ('229  177', 1), ('33  637', 1), ('57  1139', 1), ('138889', 1), ('543  887', 2), ('127068', 1), ('537  1181', 1), ('125484', 1), ('537  1056', 2), ('127916', 1), ('538  510', 1), ('126404', 1), ('537  1127', 2), ('121446', 1), ('536  925', 3), ('126199', 1), ('537  1112', 3), ('88794', 3), ('85  91', 1), ('21  804', 1), ('18  91', 1), ('133039', 1), ('540  945', 1), ('98647', 3), ('240  136', 1), ('36  345', 1), ('60  566', 1), ('99019', 3), ('245  116', 1), ('38  38', 1), ('62  185', 1), ('145049', 1), ('544  1064', 2), ('128519', 1), ('538  948', 1), ('127099', 1), ('537  1187', 1), ('141183', 1), ('543  1068', 1), ('89481', 2), ('94  400', 1), ('24  128', 1), ('144492', 1), ('544  1024', 2), ('141736', 1), ('543  1107', 4), ('88395', 3), ('79  317', 1), ('20  417', 1), ('12  317', 1), ('87781', 3), ('71  404', 1), ('18  395', 1), ('4  404', 1), ('124122', 1), ('537  943', 2), ('90822', 3), ('108  30', 1), ('2  9', 1), ('27   ...

# %% [markdown]
# ### Laplacian matrix and spectral clustering of the graph

# %%
laplacian = nx.directed_laplacian_matrix(case_cite_graph)

# %%
eig_vals, eig_vectors = eigh(laplacian.A)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-111-68ae2c0c90e1> in <module>()
# ----> 1 eig_vals, eig_vectors = eigh(laplacian.A)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/linalg/linalg.py in eigh(a, UPLO)
#    1289
#    1290     signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1291     w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1292     w = w.astype(_realType(result_t), copy=False)
#    1293     vt = vt.astype(result_t, copy=False)
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(eig_vectors[:,1], eig_vectors[:,2],'o')
plt.xlabel('second eigenvector value')
plt.ylabel('third eigenvector value')
plt.show()

# %%
X = np.array(list(zip(eig_vectors[:,1], eig_vectors[:,2])))

# %% [markdown]
# ### Eclust analysis of the clustering

# %%
cluster_range = range(1, 20)
cluster_errors = []
for num_clusters in cluster_range:
    kmean = KMeans(num_clusters)
    kmean.fit(X)
    cluster_errors.append(kmean.inertia_)

clusters_df = pandas.DataFrame({ "num_clusters":cluster_range, "cluster_errors": cluster_errors })
plt.figure(figsize=(12,6))
plt.plot(clusters_df.num_clusters, clusters_df.cluster_errors, marker = "o" )

# %%
clusters_df

# %% [markdown]
# ### Apply K-means to the dataset

# %%
kmeans = KMeans(n_clusters=7)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
labels

# %%
plt.figure()
plt.plot(eig_vectors[:,1], eig_vectors[:,2],'o')
plt.plot(centroids[:,0], centroids[:,1],'+')
plt.xlabel('second eigenvector value')
plt.ylabel('third eigenvector value')
plt.show()

# %%
print(len(case_cite_graph.nodes()))
print(len(labels))

# %%
len(missing_html)

# %% [markdown]
# ### Assign cluster ID to the dataset

# %%
for i in range(len(labels)):
    if nodes[i] in list(map(int, case_cite_graph.nodes())):
        mask = case_relation.id.astype('int64') == nodes[i]
        case_relation.loc[mask, 'cluster_id'] = labels[i]

# %%
case_relation.head()
